# %% [markdown]
# ![](images/mk.png)
#
# <h1><center>ONLINE SUPPLEMENT</center></h1>
#
# John McLevey & Reid-McIlroy-Young. **Introducing *metaknowledge*: Software for Computational Research in Information Science, Science of Science, and Network Analysis.** *Journal of Informetrics*. XX(XX):XX-XX.
#
# <h1><center>Part 2: Standard and Multi-RPYS Analysis</center></h1>
#
# These supplementary notebooks were prepared by Dr. [John McLevey](http://www.johnmclevey.com/) (University of Waterloo), [Reid McIlroy-Young](http://reidmcy.com/) (University of Chicago), and [Jillian Anderson](http://networkslab.org/) (NetLab, University of Waterloo). The code in this notebook is current as of *metaknowledge* version XXX.

# %%
# %matplotlib inline

import metaknowledge as mk
import matplotlib.pyplot as plt
import seaborn as sns
import pandas

sns.set_style(style="white") # change the default background plot colour
sns.set(font_scale=.7)

plt.rc("savefig", dpi=300) # improve default resolution of graphics

# %%
RC = mk.RecordCollection('raw_data/imetrics/', cached = True)

# %% [markdown]
# ## Standard Reference Publication Year Spectroscopy (RPYS)

# %%
stan_results = RC.rpys(1900,2015) # takes a min and max year

# %%
dev_line_color = sns.xkcd_rgb["pale red"]

with sns.axes_style("white"):
    plt.plot(stan_results['year'],stan_results['abs-deviation'], color = dev_line_color)
    plt.plot([1900,2015], [0, 0], linewidth=1, color = "black") # add a line at 0 to emphasize deviations.
    sns.despine()
plt.savefig("figures/rpys_standard.pdf")

# %% [markdown]
# Once we identify a year (or years) that we want to inspect further, we can use the `getCitations` method to see the published records.

# %%
year_results = RC.getCitations('year', 1963, pandasFriendly=True)
pandas.DataFrame(year_results).sort_values(['num-cites'], ascending=False)
# Out:
#                         author  \
# 145     De Solla Price Derek J
# 8                   Kessler Mm
# 149              Price D J D S
# 113                 Garfield E
# 229                  Price Djd
# 57                  Abramson N
# 74                     Ward Jh
# 242                Weinberg Am
# 90                   Kelly G A
# 49                    Price Dd
# 73           De Solla Price Dj
# 64                  Kessler Mm
# 211                   Irwin Jo
# 225                Kessler M M
# 206                   Salton G
# 98   Price John Derek De Solla
# 111              Price Dj De S
# 122                   March Jg
# 193              Popper Karl R
# 50                    Arrow Kj
# 70                  Toynbee Aj
# 246                  Klare G R
# 175               Mandelbrot B
# 19          De Solla Price D J
# 131                   Asimov I
# 198               Chomsky Noam
# 42                     Cole Pf
# 241                    Sokal R
# 87                Mandelbrot B
# 123                  Desolla D
# ..                         ...
# 137                 Buchholz W
# 138                  Vapnik Vn
# 139                Rosenberg N
# 106                   Dalkey N
# 105                     Ames E
# 104           *Org Ec Coop Dev
# 86                 Reynolds Es
# 72                    Price Dd
# 75                  Freeman Rr
# 76                Alexander Cn
# 77                   Medawar P
# 78                  Kendall Mg
# 79                 Griliches Z
# 80                    Popper K
# 82                        None
# 84                 Ackrill J L
# 85          De Solla Price D J
# 88                  Anderson K
# 103                     Marx M
# 91                  Bourne C P
# 92                    Harper S
# 93                  Britton Jp
# 94                  Shannon Ce
# 95                    Brown Af
# 96                    Price Dj
# 97                 Brinegar Cs
# 100         De Solla Price D J
# 101                       None
# 102                   Price Dj
# 247                    Riley M
#
#                                             citeString  \
# 145   de Solla Price Derek J, 1963, LITTLE SCI BIG SCI
# 8    KESSLER MM, 1963, AM DOC, V14, P10, DOI 10.100...
# 149         Price D. J. d. S, 1963, LITTLE SCI BIG SCI
# 113  GARFIELD E, 1963, AM DOC, V14, P195, DOI 10.10...
# 229           PRICE DJD, 1963, LITTLE SCI BIG SCI, P87
# 57             Abramson N., 1963, INFORM THEORY CODING
# 74   WARD JH, 1963, J AM STAT ASSOC, V58, P236, DOI...
# 242  WEINBERG AM, 1963, MINERVA, V1, P159, DOI 10.1...
# 90             Kelly G. A., 1963, THEORY PERSONALITY P
# 49             PRICE DD, 1963, LITTLE SCI BIG SCI, P65
# 73       De Solla Price D.J., 1963, BIG SCI LITTLE SCI
# 64   KESSLER MM, 1963, INFORM STORAGE RET, V1, P169...
# 211  IRWIN JO, 1963, J R STAT SOC SER A-G, V126, P1...
# 225            Kessler M. M., 1963, AM DOC, V62, P2437
# 206  SALTON G, 1963, J ACM, V10, P440, DOI 10.1145/...
# 98   Price John Derek de Solla, 1963, LITTLE SCI BI...
# 111                  Price D.J. de S, 1963, LITTLE SCI
# 122                  March JG, 1963, BEHAV THEORY FIRM
# 193         Popper Karl R., 1963, CONJECTURES REFUTATI
# 50                Arrow KJ, 1963, SOCIAL CHOICE INDIVI
# 70              TOYNBEE AJ, 1963, INTRO GENESIS CIVILI
# 246            Klare G. R., 1963, MEASUREMENT READABIL
# 175  MANDELBROT B, 1963, J BUS, V36, P394, DOI 10.1...
# 19      De Solla Price D. J., 1963, LITTLE SCI BIG SCI
# 131                      Asimov I., 1963, GENETIC CODE
# 198     CHOMSKY NOAM, 1963, HDB MATH PSYCHOL, V2, P419
# 42                       COLE PF, 1963, J DOC, V19, P1
# 241               Sokal R., 1963, PRINCIPLES NUMERICAL
# 87   MANDELBROT B, 1963, J POLIT ECON, V71, P421, D...
# 123               DeSolla D., 1963, LITTLE SCI BIG SCI
# ..                                                 ...
# 137              BUCHHOLZ W, 1963, IBM SYST J, V2, P86
# 138  Vapnik V.N., 1963, Avtomatika i Telemekhanika,...
# 139          ROSENBERG N, 1963, J ECON HIST, V23, P414
# 106  DALKEY N, 1963, MANAGE SCI, V9, P458, DOI 10.1...
# 105            AMES E, 1963, EC J             MAR, P13
# 104       *ORG EC COOP DEV, 1963, DASPD6247 OECD DIR S
# 86   REYNOLDS ES, 1963, J CELL BIOL, V17, P208, DOI...
# 72                  PRICE DD, 1963, LITTLE SIC BIG SCI
# 75   FREEMAN RR, 1963, J CHEM DOC, V3, P16, DOI 10....
# 76   ALEXANDER CN, 1963, SOCIOMETRY, V26, P268, DOI...
# 77                Medawar P, 1963, LISTENER, V70, P377
# 78                   KENDALL MG, 1963, ADV THEORY STAT
# 79             GRILICHES Z, 1963, J POLITICAL EC, V331
# 80               Popper K., 1963, CONJECTURES REFUTATI
# 82                1963, GRAND LAROUSSE ENCYC, V7, P786
# 84           ACKRILL J. L., 1963, ARISTOTLE CATEGORIES
# 85   De Solla Price D. J., 1963, LITTLE SCI BIGSCIE...
# 88           ANDERSON K, 1963, SPEECH MONOGR, V30, P77
# 103                Marx M., 1963, SYSTEMS THEORIES PSY
# 91            Bourne C. P., 1963, METHODS INFORM HANDL
# 92              HARPER S, 1963, LIB SERVICE LABOR, P39
# 93              BRITTON JP, 1963, PRODUCTIVITY SCI PRE
# 94            Shannon C.E., 1963, MATH THEORY COMMUNIC
# 95       BROWN AF, 1963, NORMAL REVERSE ENGLI, V1, pR5
# 96              PRICE DJ, 1963, TECHNOL CULT, V6, P553
# 97   Brinegar CS, 1963, J AM STAT ASSOC, V58, P85, ...
# 100   de Solla Price D. J., 1963, LITTLE SCI BIG SIENC
# 101                         1963, ROGETS INT THESAURUS
# 102                     PRICE DJ, 1963, LITTLE SCIENCE
# 247                RILEY M, 1963, SOCIOLOGICAL RES, V1
#
#      fraction-cites-overall  fraction-cites-year                     journal  \
# 145                0.187050             0.187050          LITTLE SCI BIG SCI
# 8                  0.128297             0.128297                      AM DOC
# 149                0.100719             0.100719          LITTLE SCI BIG SCI
# 113                0.083933             0.083933                      AM DOC
# 229                0.021583             0.021583          LITTLE SCI BIG SCI
# 57                 0.020384             0.020384        INFORM THEORY CODING
# 74                 0.014388             0.014388             J AM STAT ASSOC
# 242                0.013189             0.013189                     MINERVA
# 90                 0.010791             0.010791        THEORY PERSONALITY P
# 49                 0.010791             0.010791          LITTLE SCI BIG SCI
# 73                 0.010791             0.010791          BIG SCI LITTLE SCI
# 64                 0.009592             0.009592          INFORM STORAGE RET
# 211                0.007194             0.007194        J R STAT SOC SER A-G
# 225                0.007194             0.007194                      AM DOC
# 206                0.007194             0.007194                       J ACM
# 98                 0.005995             0.005995          LITTLE SCI BIG SCI
# 111                0.005995             0.005995                  LITTLE SCI
# 122                0.005995             0.005995           BEHAV THEORY FIRM
# 193                0.004796             0.004796        CONJECTURES REFUTATI
# 50                 0.004796             0.004796        SOCIAL CHOICE INDIVI
# 70                 0.004796             0.004796        INTRO GENESIS CIVILI
# 246                0.004796             0.004796        MEASUREMENT READABIL
# 175                0.004796             0.004796                       J BUS
# 19                 0.004796             0.004796          LITTLE SCI BIG SCI
# 131                0.003597             0.003597                GENETIC CODE
# 198                0.003597             0.003597            HDB MATH PSYCHOL
# 42                 0.003597             0.003597                       J DOC
# 241                0.003597             0.003597        PRINCIPLES NUMERICAL
# 87                 0.003597             0.003597                J POLIT ECON
# 123                0.003597             0.003597          LITTLE SCI BIG SCI
# ..                      ...                  ...                         ...
# 137                0.001199             0.001199                  IBM SYST J
# 138                0.001199             0.001199  AVTOMATIKA I TELEMEKHANIKA
# 139                0.001199             0.001199                 J ECON HIST
# 106                0.001199             0.001199                  MANAGE SCI
# 105                0.001199             0.001199        EC J             MAR
# 104                0.001199             0.001199        DASPD6247 OECD DIR S
# 86                 0.001199             0.001199                 J CELL BIOL
# 72                 0.001199             0.001199          LITTLE SIC BIG SCI
# 75                 0.001199             0.001199                  J CHEM DOC
# 76                 0.001199             0.001199                  SOCIOMETRY
# 77                 0.001199             0.001199                    LISTENER
# 78                 0.001199             0.001199             ADV THEORY STAT
# 79                 0.001199             0.001199              J POLITICAL EC
# 80                 0.001199             0.001199        CONJECTURES REFUTATI
# 82                 0.001199             0.001199        GRAND LAROUSSE ENCYC
# 84                 0.001199             0.001199        ARISTOTLE CATEGORIES
# 85                 0.001199             0.001199        LITTLE SCI BIGSCIENC
# 88                 0.001199             0.001199               SPEECH MONOGR
# 103                0.001199             0.001199        SYSTEMS THEORIES PSY
# 91                 0.001199             0.001199        METHODS INFORM HANDL
# 92                 0.001199             0.001199           LIB SERVICE LABOR
# 93                 0.001199             0.001199        PRODUCTIVITY SCI PRE
# 94                 0.001199             0.001199        MATH THEORY COMMUNIC
# 95                 0.001199             0.001199        NORMAL REVERSE ENGLI
# 96                 0.001199             0.001199                TECHNOL CULT
# 97                 0.001199             0.001199             J AM STAT ASSOC
# 100                0.001199             0.001199        LITTLE SCI BIG SIENC
# 101                0.001199             0.001199        ROGETS INT THESAURUS
# 102                0.001199             0.001199              LITTLE SCIENCE
# 247                0.001199             0.001199            SOCIOLOGICAL RES
#
#      num-cites  year
# 145        156  1963
# 8          107  1963
# 149         84  1963
# 113         70  1963
# 229         18  1963
# 57          17  1963
# 74          12  1963
# 242         11  1963
# 90           9  1963
# 49           9  1963
# 73           9  1963
# 64           8  1963
# 211          6  1963
# 225          6  1963
# 206          6  1963
# 98           5  1963
# 111          5  1963
# 122          5  1963
# 193          4  1963
# 50           4  1963
# 70           4  1963
# 246          4  1963
# 175          4  1963
# 19           4  1963
# 131          3  1963
# 198          3  1963
# 42           3  1963
# 241          3  1963
# 87           3  1963
# 123          3  1963
# ..         ...   ...
# 137          1  1963
# 138          1  1963
# 139          1  1963
# 106          1  1963
# 105          1  1963
# 104          1  1963
# 86           1  1963
# 72           1  1963
# 75           1  1963
# 76           1  1963
# 77           1  1963
# 78           1  1963
# 79           1  1963
# 80           1  1963
# 82           1  1963
# 84           1  1963
# 85           1  1963
# 88           1  1963
# 103          1  1963
# 91           1  1963
# 92           1  1963
# 93           1  1963
# 94           1  1963
# 95           1  1963
# 96           1  1963
# 97           1  1963
# 100          1  1963
# 101          1  1963
# 102          1  1963
# 247          1  1963
#
# [248 rows x 7 columns]

# %% [markdown]
# ### Multi RPYS

# %% [markdown]
# As described in the article, Multi RPYS segements the articles by publication date and performs a seperate RPYS analysis for each year. The following code executes that workflow, and then creates a table that can be plotted as a heatmap.

# %%
minYear = 1950
maxYear = 2015

years = range(minYear, maxYear+1)

dictionary = {'CPY': [],
             "abs-deviation": [],
             "num-cites": [],
             "rank": [],
             "RPY": []}
for i in years:
    try:
        RCyear = RC.yearSplit(i, i)
        if len(RCyear) > 0:
            rpys = RCyear.rpys(minYear=minYear, maxYear=i)
            length = len(rpys['year'])
            rpys['CPY'] = [i]*length

            dictionary['CPY'] += rpys['CPY']
            dictionary['abs-deviation'] += rpys['abs-deviation']
            dictionary['num-cites'] += rpys['count']
            dictionary['rank'] += rpys['rank']
            dictionary['RPY'] += rpys['year']
    except:
        pass

multi_rpys = pandas.DataFrame.from_dict(dictionary)
multi_rpys.to_csv("generated_datasets/multi_rpys.csv")

# %%
hm_table = multi_rpys.pivot('CPY', 'RPY', 'rank')
hm_table
# Out:
# RPY   1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  ...   2006  \
# CPY                                                               ...
# 1978  22.0   0.0   0.0  23.0   8.0   9.0   5.0  24.0   6.0  10.0  ...    NaN
# 1979  10.0  22.0   7.0  21.0  11.0  12.0   8.0  28.0   9.0  13.0  ...    NaN
# 1980   6.0  10.0   7.0  11.0  12.0   8.0  23.0  13.0  14.0  25.0  ...    NaN
# 1981  12.0   0.0  13.0  24.0   0.0  14.0  15.0  16.0   9.0  25.0  ...    NaN
# 1982  12.0  13.0   0.0  26.0   9.0  14.0   7.0  32.0  24.0   4.0  ...    NaN
# 1983  25.0   0.0   0.0  22.0   0.0  23.0  13.0  26.0  14.0   0.0  ...    NaN
# 1984  10.0  23.0   7.0  12.0  13.0  24.0  14.0  28.0  15.0   3.0  ...    NaN
# 1985  11.0  12.0   6.0  13.0   8.0  14.0  15.0  16.0  27.0  17.0  ...    NaN
# 1986   0.0  29.0   0.0   0.0  14.0  15.0  16.0  17.0   0.0  10.0  ...    NaN
# 1987   8.0  27.0  11.0  12.0  28.0   9.0  29.0  13.0  14.0  15.0  ...    NaN
# 1988   0.0   9.0   0.0  29.0  10.0  11.0  12.0  13.0  30.0  33.0  ...    NaN
# 1989   8.0  32.0   9.0  13.0  28.0  14.0   0.0  15.0  10.0  16.0  ...    NaN
# 1990  14.0   0.0   0.0  32.0   0.0   0.0  33.0  36.0   7.0  17.0  ...    NaN
# 1991  11.0  12.0  13.0  14.0  31.0  15.0  16.0  39.0   0.0  17.0  ...    NaN
# 1992  15.0  16.0   0.0   0.0  31.0  32.0   0.0  33.0  17.0  18.0  ...    NaN
# 1993   0.0  13.0  14.0  35.0   0.0   9.0  32.0  37.0  10.0  15.0  ...    NaN
# 1994  14.0   0.0   0.0  36.0   0.0  16.0  32.0  33.0   9.0  17.0  ...    NaN
# 1995  15.0  32.0  16.0  17.0   0.0  18.0  19.0  37.0  20.0  12.0  ...    NaN
# 1996   0.0   0.0   0.0   0.0  37.0  14.0   0.0  15.0  39.0   8.0  ...    NaN
# 1997   0.0  35.0  14.0   0.0  15.0   0.0  16.0  36.0  17.0   0.0  ...    NaN
# 1998  17.0  18.0   0.0  19.0  20.0  40.0   0.0  21.0  22.0   0.0  ...    NaN
# 1999   0.0  39.0  13.0  33.0  34.0  14.0   0.0  40.0  19.0  15.0  ...    NaN
# 2000  35.0  18.0  12.0  39.0   6.0  19.0  20.0  13.0  40.0  21.0  ...    NaN
# 2001   9.0  15.0  13.0  42.0  10.0  38.0  16.0  17.0  39.0  14.0  ...    NaN
# 2002  19.0  17.0   0.0  43.0  11.0  39.0  20.0  21.0   8.0  40.0  ...    NaN
# 2003  15.0  17.0  12.0  42.0  16.0  43.0  18.0  19.0  20.0  13.0  ...    NaN
# 2004  11.0  14.0  15.0  44.0  10.0  42.0  16.0  46.0   8.0  13.0  ...    NaN
# 2005  16.0  17.0  10.0  45.0  18.0  19.0  13.0  42.0  46.0  14.0  ...    NaN
# 2006  11.0  18.0   0.0  19.0  12.0  20.0  21.0  22.0  23.0  46.0  ...    0.0
# 2007  10.0  40.0  15.0  16.0  11.0  17.0  46.0  41.0  18.0  19.0  ...    0.0
# 2008  19.0  20.0  44.0  16.0  17.0  45.0  41.0  21.0  18.0  13.0  ...   59.0
# 2009   5.0  48.0  16.0  17.0   6.0  50.0  18.0  47.0  14.0  15.0  ...   60.0
# 2010  13.0  45.0  20.0  16.0  21.0  46.0  14.0  47.0  48.0  10.0  ...   42.0
# 2011  17.0  19.0  12.0  49.0  20.0  53.0   9.0  18.0  47.0  45.0  ...   41.0
# 2012  18.0  47.0  22.0  19.0  23.0  52.0  20.0  24.0  21.0  25.0  ...   41.0
# 2013  18.0  19.0  14.0  50.0  12.0  54.0  15.0  20.0  51.0  13.0  ...   43.0
# 2014   8.0  52.0  12.0  13.0  19.0  53.0  20.0  50.0  21.0  17.0  ...   41.0
# 2015  10.0  47.0  16.0  49.0  18.0  50.0  12.0  51.0  48.0  19.0  ...    6.0
#
# RPY   2007  2008  2009  2010  2011  2012  2013  2014  2015
# CPY
# 1978   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1979   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1980   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1981   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1982   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1983   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1984   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1985   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1986   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1987   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1988   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1989   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1990   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1991   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1992   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1993   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1994   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1995   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1998   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1999   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2000   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2001   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2002   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2003   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2004   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2005   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2006   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2007   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2008   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2009  59.0   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2010  60.0  61.0   0.0   0.0   NaN   NaN   NaN   NaN   NaN
# 2011  42.0  61.0  62.0   0.0   0.0   NaN   NaN   NaN   NaN
# 2012  42.0  43.0  62.0  63.0   0.0   0.0   NaN   NaN   NaN
# 2013  44.0  45.0  46.0  64.0  63.0   0.0   0.0   NaN   NaN
# 2014  42.0  43.0  44.0  45.0  64.0  65.0   0.0   0.0   NaN
# 2015  40.0  41.0  42.0  43.0  65.0  66.0  44.0   0.0   0.0
#
# [38 rows x 66 columns]

# %%
with sns.axes_style("white"):
    sns.heatmap(hm_table, square = False, cmap="YlGnBu", cbar_kws={"orientation": "horizontal"})
    plt.xlabel('Reference Publication Year', size = 8)
    plt.ylabel('Citing Publication Year', size = 8)
    sns.despine()
    plt.tight_layout()
plt.savefig("figures/rpys_multi.pdf")

# %% [markdown]
# # Interactive Standard and Multi RPYS Graphs with *mkD3*

# %% [markdown]
# Exploratory RPYS analysis is much easier and faster with interactive graphs.

# %% [markdown]
# ### Standard RPYS

# %%
# Create the RPYS File
standard_rpys = pandas.DataFrame.from_dict(stan_results)
standard_rpys.to_csv("generated_datasets/standard_rpys.csv")

# Create the Citation File
cits = RC.getCitations()
citations = pandas.DataFrame.from_dict(cits)
citations.to_csv("generated_datasets/standard_citation.csv")

# Create Link to Graphs
from IPython.display import display, HTML, DisplayObject
display(HTML('<a href="mkD3_static/standardBar.html" target="_blank">Open standard RPYS bar graph.</a>'))
display(HTML('<a href="mkD3_static/standardLine.html" target="_blank">Open standard RPYS line graph.</a>'))
# Out:
# <a href="mkD3_static/standardBar.html" target="_blank">Open standard RPYS bar graph.</a>
# <a href="mkD3_static/standardLine.html" target="_blank">Open standard RPYS line graph.</a>

# %% [markdown]
# ### Multi RPYS

# %% [markdown]
# A multi RPYS file was created earlier. Now we just need to create the citation file.

# %%
dictionary = {"author": [],
              "journal": [],
              "cite-string": [],
              "num-cites": [],
              "RPY": [],
              "CPY": []}

for i in years:
    try:
        RCyear = RC.yearSplit(i, i)
        if len(RCyear) > 0:
            citations = RCyear.getCitations(pandasFriendly=True)
            length = len(citations['year'])
            citations['CPY'] = [i]*length

            dictionary['CPY'] += citations['CPY']
            dictionary['author'] += citations['author']
            dictionary['journal'] += citations['journal']
            dictionary['cite-string'] += citations['citeString']
            dictionary['num-cites'] += citations['num-cites']
            dictionary['RPY'] += citations['year']
    except:
        pass

multi_citations = pandas.DataFrame.from_dict(dictionary)
multi_citations.to_csv("generated_datasets/multi_citation.csv")


# Create Link to Heatmap
display(HTML('<a href="mkD3_static/multiRPYS.html" target="_blank">Open multi RPYS heatmap.</a>'))
# Out:
# <a href="mkD3_static/multiRPYS.html" target="_blank">Open multi RPYS heatmap.</a>
